# %%
1.Who devloped python programming language?
Guido Van Rossum

2.Which type of programming language python support?
object-oriented programming language

3.Is Python Case Sensitive While Dealing with Identifiers?
Yes

4. correct python file extension is .py

5 is python is compiled or interpreted?
python is interpreted code

6.name a few blocks of code used to define in python language?
if , elif ,else 

7. State a character used to give single-line comments in Python?
(#) is the character is used to give single line comments in python.

8. "import sys
sys.version" is used to find version of python.

9.Python supports the creation of anonymous functions at runtime, using a construct called "Lambda"

10.What does pip stand for python? 
pip is package manager for python.that we can use to install packages which are not come with it.

11. Mention a few built-in functions in python? 
int()
list[]
set{}
disc{}
len{}

12. What is the maximum possible length of an identifier in Python? 
maximum possible length of an identifier in Python is 79 charactors.

13. What are the benefits of using Python? 
Python programming language is a general-purpose, interpreted, and high-level language that mainly offers code readability.

14. How is memory managed in Python? 
Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager. The Python memory manager has different components which deal with various dynamic storage management aspects, like sharing, segmentation, preallocation or caching.


15. How to install Python on Windows and set path variables?
step 1 . download latest version of Python from official site.
step 2. Run the Installer.
step 3.open cmd (using win+R)
step 4 now type python in cmd And hit enter and check version of python.
step 5 Now time to set path. now go to cmd type "Environment Variables" and hit enter now go to system environment variables and do edit.
step 6 Under system environment variables. scroll down and find 'Path'veriable then click edit .
step 7 Now you have to give new 'Path' like C/python**/python.exe where ** is the version.
    that's it 
    now just Restart cmd.
16. is indentation required in python? 
 yes indentation is required in python.in python indentation is use to define block of code such as a functions defination , loop, control structure.
    for example : 
    for i in range(10):
    print(i)
